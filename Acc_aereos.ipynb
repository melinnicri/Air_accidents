# %% [markdown]
# Importar librerías

# %%
# import libraries
import csv
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import pandas as pd

# %%
# Import .csv file
data = pd.read_csv(r"Accidentes_aereos.csv", sep = ",", encoding = "latin-1")

# %%
#Check data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5008 entries, 0 to 5007
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      5008 non-null   int64
#  1   fecha_mes               5008 non-null   object
#  2   year                    5008 non-null   int64
#  3   hora declarada          5008 non-null   object
#  4   ruta_inicio             5008 non-null   object
#  5   ruta_final              5008 non-null   object
#  6   operador                5008 non-null   object
#  7   flight_no               5008 non-null   object
#  8   route                   5008 non-null   object
#  9   ac_type                 5008 non-null   object
#  10  registration            5008 non-null   object
#  11  cn_ln                   5008 non-null   object
#  12  all_aboard              5008 non-null   int64
#  13  pasajeros_a_bordo       5008 non-null   int64
# ...

# %%
# See data
data.head(5)
# Out:
#    Id     fecha_mes  year hora declarada         ruta_inicio  \
# 0   0  September 17  1908          17:18           Fort Myer
# 1   1  September 07  1909          00:00     Juvisy-sur-Orge
# 2   2       July 12  1912          06:30       Atlantic City
# 3   3     August 06  1913          00:00            Victoria
# 4   4  September 09  1913          18:30  Over the North Sea
#
#                ruta_final              operador flight_no  \
# 0                Virginia  Military - U.S. Army         0
# 1                  France                     0         0
# 2              New Jersey  Military - U.S. Navy         0
# 3        British Columbia                Canada   Private
# 4  Military - German Navy                     0         0
#
#                     route           ac_type      registration cn_ln  \
# 0           Demonstration  Wright Flyer III                 0     1
# 1                Air show    Wright Byplane               SC1     0
# ...

# %%
# Change NaN to 0
data.fillna(0, inplace=True)

# %%
# Verify change
data.isnull().sum()
# Out:
# Id                        0
# fecha_mes                 0
# year                      0
# hora declarada            0
# ruta_inicio               0
# ruta_final                0
# operador                  0
# flight_no                 0
# route                     0
# ac_type                   0
# registration              0
# cn_ln                     0
# all_aboard                0
# pasajeros_a_bordo         0
# crew_aboard               0
# cantidad de fallecidos    0
# passenger_fatalities      0
# crew_fatalities           0
# ground                    0
# summary                   0
# dtype: int64

# %%
# Rename column
data = data.rename(columns={'fecha_aÃ±o': 'year'})

# %%
# Change ? to 0
data_cambio = data["operador"].str.contains("\?")
data["operador"][data_cambio] = 0
# Out:
# C:\Users\56988\AppData\Local\Temp\ipykernel_10668\1458605204.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["operador"][data_cambio] = 0

# %%
# Convert non-numeric values to NaN values (not a number)
data["all_aboard"] = pd.to_numeric(data["all_aboard"], errors='coerce')

# %%
# Change NaNs to 0
data["all_aboard"] = data["all_aboard"].fillna(0)

# %%
# Unique values "all_aboard" column
data_id = data["all_aboard"].unique()

# %%
# See result
print(data_id)
# Out:
# [          2           1           5           0          28          41
#           19          20          22          21          24          16
#           18          14           8           3          49          45
#            7          17         555          25           4          15
#           11          29        1535         590           6          10
#           86          12           9          13         151         239
#          704         911       10519         963        1165         120
#         5034          76        1317          83          50         195
#         4202        2312        1016         174        1007        1926
#           97       30014        1439        1043        1475        1135
#         1930        1501        2207          36          34        2309
#        32052        4401        1504          35          39        6149
#         2085          31          23        2072          27        1031
# ...

# %%
# Change data type to int32
data["all_aboard"] = data["all_aboard"].astype('int32')

# %%
# Change data type to int32
data["Id"] = data["Id"].astype('int32')

# %%
# Change data type to int32
data["year"] = data["year"].astype('int32')

# %%
# Unique values column
data_id = data["pasajeros_a_bordo"].unique()

# %%
# See them
print(data_id)
# Out:
# [          1           0          12           6           2           4
#            5           3           9           7          11         102
#           13           8          16          41         634          10
#         1428        1419        1088        1027        2020        1772
#           20         528        6606        2301         123         198
#           37          18          15        1695       30002          14
#          301         129         715          36        4305        4040
#         1432         255        5928        5210          25          21
#           23          17          31          28          19          30
#         5610          26         204          33          24          27
#         9514          22        4513       32738          55          46
#           40          44          47          34        9378          38
#         3274        2944          49        2450          48        2086
# ...

# %%
data["pasajeros_a_bordo"] = pd.to_numeric(data["pasajeros_a_bordo"], errors='coerce')

# %%
data["pasajeros_a_bordo"] = data["pasajeros_a_bordo"].fillna(0)

# %%
data_id = data["pasajeros_a_bordo"].unique()

# %%
print(data_id)
# Out:
# [          1           0          12           6           2           4
#            5           3           9           7          11         102
#           13           8          16          41         634          10
#         1428        1419        1088        1027        2020        1772
#           20         528        6606        2301         123         198
#           37          18          15        1695       30002          14
#          301         129         715          36        4305        4040
#         1432         255        5928        5210          25          21
#           23          17          31          28          19          30
#         5610          26         204          33          24          27
#         9514          22        4513       32738          55          46
#           40          44          47          34        9378          38
#         3274        2944          49        2450          48        2086
# ...

# %%
data["pasajeros_a_bordo"] = data["pasajeros_a_bordo"].astype('int32')

# %%
data["pasajeros_a_bordo"].unique()
# Out:
# array([          1,           0,          12,           6,           2,
#                  4,           5,           3,           9,           7,
#                 11,         102,          13,           8,          16,
#                 41,         634,          10,        1428,        1419,
#               1088,        1027,        2020,        1772,          20,
#                528,        6606,        2301,         123,         198,
#                 37,          18,          15,        1695,       30002,
#                 14,         301,         129,         715,          36,
#               4305,        4040,        1432,         255,        5928,
#               5210,          25,          21,          23,          17,
#                 31,          28,          19,          30,        5610,
#                 26,         204,          33,          24,          27,
#               9514,          22,        4513,       32738,          55,
# ...

# %%
data_id = data["crew_aboard"].unique()

# %%
print(data_id)
# Out:
# [         1          5          0         14         41         19
#          23         18          2          3         49         17
#           4         52         43          6          9         54
#           7         15         10         11         83         13
#          61          8         12       1299       1907       5494
#          16         25         26         20         35         22
#          21         28         32         31         44         69
#          37         27         40         78         46         55
#        7400         53         45         63         29         33
#         122         30       6079         59        149         67
#          73         36         39         42         91     141294
#          68         60         24         57         86         34
#          47         76         87         96        102         85
#          48         95         74         51         81         79
# ...

# %%
data["crew_aboard"] = pd.to_numeric(data["crew_aboard"], errors='coerce')

# %%
data["crew_aboard"] = data["crew_aboard"].fillna(0)

# %%
data_id = data["crew_aboard"].unique()

# %%
print(data_id)
# Out:
# [         1          5          0         14         41         19
#          23         18          2          3         49         17
#           4         52         43          6          9         54
#           7         15         10         11         83         13
#          61          8         12       1299       1907       5494
#          16         25         26         20         35         22
#          21         28         32         31         44         69
#          37         27         40         78         46         55
#        7400         53         45         63         29         33
#         122         30       6079         59        149         67
#          73         36         39         42         91     141294
#          68         60         24         57         86         34
#          47         76         87         96        102         85
#          48         95         74         51         81         79
# ...

# %%
data["crew_aboard"] = data["crew_aboard"].astype('int32')

# %%
data_id = data["cantidad de fallecidos"].unique()

# %%
print(data_id)
# Out:
# [    1     5     0    28    17    19    20    22    27    21    24    14
#     18     3     2     4    43    34     7     8     6    15     9    10
#    178    12    73    11    50    13    35    16    25    29    26    36
#     23    31    30    59    45    44    39    53    40    62    41    32
#     33    37    48    55    38    58    46    56    70    52    87    42
#     47    66    67    74   128    57    61    65    64    80  4418    51
#     54    63    72    69    78    83    77    76   111    81    84    86
#     97   118    49    79   121    85    68   133    82   126   107    98
#    123   155    95   100   120    90    92   102   109    99    71    93
#    163   115   104   112   156   108   174   103   176    89   122   116
#    106   298   346    75   191   188   117   154   583   137   183   258
#    146   301    60   173   132   145   172   269   181 46871   110   329
#    134   248    94   167   149   140   101   124   259   287   171   127
# ...

# %%
data["cantidad de fallecidos"] = pd.to_numeric(data["cantidad de fallecidos"], errors='coerce')

# %%
data["cantidad de fallecidos"] = data["cantidad de fallecidos"].fillna(0)

# %%
data_id = data["cantidad de fallecidos"].unique()

# %%
print(data_id)
# Out:
# [    1     5     0    28    17    19    20    22    27    21    24    14
#     18     3     2     4    43    34     7     8     6    15     9    10
#    178    12    73    11    50    13    35    16    25    29    26    36
#     23    31    30    59    45    44    39    53    40    62    41    32
#     33    37    48    55    38    58    46    56    70    52    87    42
#     47    66    67    74   128    57    61    65    64    80  4418    51
#     54    63    72    69    78    83    77    76   111    81    84    86
#     97   118    49    79   121    85    68   133    82   126   107    98
#    123   155    95   100   120    90    92   102   109    99    71    93
#    163   115   104   112   156   108   174   103   176    89   122   116
#    106   298   346    75   191   188   117   154   583   137   183   258
#    146   301    60   173   132   145   172   269   181 46871   110   329
#    134   248    94   167   149   140   101   124   259   287   171   127
# ...

# %%
data["cantidad de fallecidos"] = data["cantidad de fallecidos"].astype('int32')

# %%
data_id = data["passenger_fatalities"].unique()

# %%
print(data_id)
# Out:
# [  1   0   2  12   4   5   3   6   7  43  13   9   8  16  14  10  37  15
#   11  21  23  17  20  19  18  30  26  24  40  27  22  31  25  55  28  44
#   38  49  33  47  48  36  29  39  52  32  34  51  80  35  58  50  41  82
#  129  46  42  57  63  45  64 117  62  79  56  99  54  71  65  59 116  61
#   60  73  77  74  95 101 107 130 112  76  94 111  75  85  78  84 108  81
#  126 124  98  88  72  70  66 149  89  93 110  69  97 100  91  90 155 104
#   53 106 115 122 148 164 170 123  83 114  87 279 335  96 102  67 182 213
#  150 113 181  68 176 146 560 131 128 175 156 257 138 166 287 162 119 246
#  158 177 169 103 307 200 520 159 172 143 290 243 144 167 121  92 223 247
#  154 133 147 125 264 127 137 160 189 212 134 316 206 222 229 236 202 135
#  136 120 151 105 228 283 217]

# %%
data["passenger_fatalities"] = data["passenger_fatalities"].astype('int32')

# %%
data_id = data["crew_fatalities"].unique()

# %%
print(data_id)
# Out:
# [  0   5  17  19   1   2   3  43   4  14   6  48   7  15  10  11  13   9
#   22   8  16  25  26  20  34  28  21  23  32  18  12  41  27  40  75  55
#   45  33  29  37 122  31  30  24  59  73  36  35  42  91  63  68  57  78
#   47  87  96 102  85  95  74  51  81  79  46  53 106 113  38  92  83  69
#   65  52  44  72 105 108 115 118  61 116  54 107 126  50  58 162  82 125
#   93 190 103 271 145 237 120  77 156 104 180  70  98 111  84 163 141 191
#  505 256 154 159 136 278 137 112 213 100 249 152 176 215  60  66 260 148
#   67  49 216 168  90  88 150 110  71]

# %%
data["crew_fatalities"] = data["crew_fatalities"].astype('int32')

# %%
data
# Out:
#         Id     fecha_mes  year hora declarada         ruta_inicio  \
# 0        0  September 17  1908          17:18           Fort Myer
# 1        1  September 07  1909          00:00     Juvisy-sur-Orge
# 2        2       July 12  1912          06:30       Atlantic City
# 3        3     August 06  1913          00:00            Victoria
# 4        4  September 09  1913          18:30  Over the North Sea
# ...    ...           ...   ...            ...                 ...
# 5003  5003      March 28  2021          18:35          Near Butte
# 5004  5004        May 21  2021          18:00         Near Kaduna
# 5005  5005       June 10  2021          08:00   Near Pyin Oo Lwin
# 5006  5006       July 04  2021          11:30             Patikul
# 5007  5007       July 06  2021          15:00              Palana
#
#                   ruta_final                       operador  \
# 0                   Virginia           Military - U.S. Army
# ...

# %%
# We save the rest of the data in a .csv file
data.to_csv('Accidentes_aereos.csv', index=False)
